# %%
import pandas as pd

# %%
pd.set_option("display.max_colwidth", None)

tickets_summary = pd.read_csv("results.csv")
tickets_summary
# Out:
#     ticket_id customer_tier           created_at channel  \
# 0  TICKET-001           VIP  2025-12-03T10:00:00   email
# 1  TICKET-002      standard  2025-12-03T11:30:00    chat
# 2  TICKET-003    enterprise  2025-12-03T12:00:00   phone
#
#                                                       summary urgency  \
# 0      The service is down and we are experiencing data loss.      P0
# 1                               I cannot login to my account.      P1
# 2  The website is slow and latency is high during peak hours.      P2
#
#    urgency_conf  \
# 0          0.95
# 1          0.80
# 2          0.70
#
#                                                                                                      action
# 0  Immediate: page on-call + create incident ticket; assign to the lead IT engineer notify account manager.
# 1             High: assign it to engineer of the team 2 and notify Product Manager and the account manager.
# ...
